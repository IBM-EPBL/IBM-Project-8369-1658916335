# %% [markdown]
# # Load Dataset

# %%
import pandas as pd
dt = pd.read_csv("/content/abalone.csv")
dt.head(5)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
dt.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
#Inserting Age Column
age=dt['Rings']+1.5
dt['Age']=age
dt.head(5)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings   Age
# 0         0.150     15  16.5
# 1         0.070      7   8.5
# 2         0.210      9  10.5
# 3         0.155     10  11.5
# 4         0.055      7   8.5

# %% [markdown]
# # **Univariate Analysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x=dt.index,y=dt['Rings'],hue=dt['Age'])

# %% [markdown]
# # Histogram

# %%
sns.histplot(x=dt['Length'],hue=dt['Age'])

# %% [markdown]
# # Density Plot

# %%
sns.kdeplot(x=dt['Diameter'],shade=True)

# %%
sns.kdeplot(x=dt['Diameter'],shade=True,hue=dt['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
sns.kdeplot(x=dt['Height'],shade=True)

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(dt["Whole weight"], color='blue')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(dt["Shell weight"], color='blue')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Bivariate Analysis**

# %% [markdown]
# # Bar Plot

# %%
sns.barplot(dt['Viscera weight'],dt['Shucked weight'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(dt['Viscera weight'],dt['Shucked weight'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Line Plot

# %%
sns.lineplot(dt["Length"],dt["Height"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Multivariate Analysis**

# %%
sns.pairplot(data=dt[["Length","Diameter","Height","Rings"]],diag_kind="kde",kind="scatter")

# %%
sns.pairplot(data=dt[["Whole weight","Shucked weight","Shell weight","Viscera weight"]],diag_kind="hist",kind="kde")

# %% [markdown]
# # **Descriptive Statistics**

# %%
dt.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings          Age
# count     4177.000000   4177.000000  4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684    11.433684
# std          0.109614      0.139203     3.224169     3.224169
# ...

# %%
dt.max()
# Out:
# Sex                    M
# Length             0.815
# Diameter            0.65
# Height              1.13
# Whole weight      2.8255
# Shucked weight     1.488
# Viscera weight      0.76
# Shell weight       1.005
# Rings                 29
# Age                 30.5
# dtype: object

# %%
dt.min()
# Out:
# Sex                    F
# Length             0.075
# Diameter           0.055
# Height               0.0
# Whole weight       0.002
# Shucked weight     0.001
# Viscera weight    0.0005
# Shell weight      0.0015
# Rings                  1
# Age                  2.5
# dtype: object

# %% [markdown]
# # Missing **Values**

# %%
dt.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# Age               False
# dtype: bool

# %% [markdown]
# # **Replacing Outliers**

# %%
q1 = dt['Age'].quantile(0.25)
q3 = dt['Age'].quantile(0.75)
iqr = q3 - q1
dt.loc[dt['Age'] < q1 - 1.5*iqr, 'Age'] = q1
dt.loc[dt['Age'] > q3 + 1.5*iqr, 'Age'] = q3
sns.boxplot(x=dt['Age'])

# %%
sns.boxplot(x=dt['Diameter'])

# %%
q1 = dt['Diameter'].quantile(0.25)
q3 = dt['Diameter'].quantile(0.75)
iqr = q3 - q1
dt.loc[dt['Diameter'] < q1 - 1.5*iqr, 'Diameter'] = q1
dt.loc[dt['Diameter'] > q3 + 1.5*iqr, 'Diameter'] = q3
sns.boxplot(x=dt['Diameter'])

# %%
sns.boxplot(x=dt['Length'])

# %%
q1 = dt['Length'].quantile(0.25)
q3 = dt['Length'].quantile(0.75)
iqr = q3 - q1
dt.loc[dt['Length'] < q1 - 1.5*iqr, 'Length'] = q1
dt.loc[dt['Length'] > q3 + 1.5*iqr, 'Length'] = q3
sns.boxplot(x=dt['Length'])

# %%
sns.boxplot(x=dt['Height'])

# %%
q1 = dt['Height'].quantile(0.25)
q3 = dt['Height'].quantile(0.75)
iqr = q3 - q1
dt.loc[dt['Height'] < q1 - 1.5*iqr, 'Height'] = q1
dt.loc[dt['Height'] > q3 + 1.5*iqr, 'Height'] = q3
sns.boxplot(x=dt['Height'])

# %% [markdown]
# # **Categorical columns and  encoding**

# %%
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder
dt.head(5)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings   Age
# 0         0.150     15  16.5
# 1         0.070      7   8.5
# 2         0.210      9  10.5
# 3         0.155     10  11.5
# 4         0.055      7   8.5

# %%
enc=LabelEncoder()
encode1=enc.fit_transform(np.array(dt['Sex']))
encode1
# Out:
# array([2, 2, 0, ..., 2, 0, 2])

# %%
dt['Sex']=encode1
dt.head(5)
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings   Age
# 0          0.1010         0.150     15  16.5
# 1          0.0485         0.070      7   8.5
# 2          0.1415         0.210      9  10.5
# 3          0.1140         0.155     10  11.5
# 4          0.0395         0.055      7   8.5

# %% [markdown]
# # **Spliting the data into dependant and independant set**

# %%
y=dt['Age']
print(y)
x=dt.drop('Age',axis=1)
x
# Out:
# 0       16.5
# 1        8.5
# 2       10.5
# 3       11.5
# 4        8.5
#         ...
# 4172    12.5
# 4173    11.5
# 4174    10.5
# 4175    11.5
# 4176    13.5
# Name: Age, Length: 4177, dtype: float64
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# ...

# %% [markdown]
# # **Scaling Independent Variables**

# %%
from sklearn.preprocessing import scale
x=scale(x)
x
# Out:
# array([[ 1.15198011, -0.63403286, -0.49155498, ..., -0.72621157,
#         -0.63821689,  1.57154357],
#        [ 1.15198011, -1.55512361, -1.55955245, ..., -1.20522124,
#         -1.21298732, -0.91001299],
#        [-1.28068972,  0.02388911,  0.09584363, ..., -0.35668983,
#         -0.20713907, -0.28962385],
#        ...,
#        [ 1.15198011,  0.63794962,  0.68324224, ...,  0.97541324,
#          0.49695471, -0.28962385],
#        [-1.28068972,  0.85725694,  0.79004199, ...,  0.73362741,
#          0.41073914,  0.02057072],
#        [ 1.15198011,  1.60290184,  1.53764022, ...,  1.78744868,
#          1.84048058,  0.64095986]])

# %% [markdown]
# # **Spliting data into training and testing datasets**

# %%
x=np.array(x)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=40)

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((3341, 9), (836, 9), (3341,), (836,))

# %% [markdown]
# # **Model Training**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_jobs = -1 , random_state = 14)
rf.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=14)

# %%
ypred=rf.predict(xtest)

# %%
ypred
# Out:
# array([15.5, 10.5,  7.5,  8.5, 11.5,  7.5, 14.5, 11.5, 15.5, 11.5,  9.5,
#        11.5, 10.5, 13.5, 13.5, 10.5,  9.5, 12.5,  9.5,  9.5, 14.5, 15.5,
#        11.5,  8.5, 14.5,  8.5, 12.5, 14.5,  5.5,  9.5,  6.5, 13.5,  8.5,
#        11.5, 12.5, 10.5,  8.5, 12.5,  6.5, 12.5, 10.5,  9.5, 10.5,  9.5,
#        16.5, 10.5,  8.5,  9.5, 11.5, 10.5,  8.5, 10.5, 13.5, 12.5,  6.5,
#        13.5, 15.5,  9.5, 13.5,  9.5, 16.5, 10.5, 11.5, 11.5, 10.5, 14.5,
#        12.5, 12.5,  9.5,  9.5,  9.5, 15.5, 14.5, 16.5, 10.5, 11.5, 11.5,
#        12.5,  9.5, 11.5, 15.5, 16.5, 12.5, 10.5,  7.5, 12.5, 10.5, 12.5,
#        13.5,  9.5, 12.5, 12.5, 12.5, 10.5, 12.5, 12.5,  9.5, 10.5, 11.5,
#        10.5, 10.5, 14.5,  9.5,  8.5, 12.5,  6.5, 10.5, 12.5, 12.5, 10.5,
#        12.5, 14.5,  5.5, 11.5, 13.5, 11.5, 12.5, 15.5, 12.5,  9.5,  7.5,
#        11.5, 10.5, 12.5, 10.5,  9.5,  8.5, 10.5, 12.5, 12.5, 13.5, 10.5,
#        13.5, 12.5, 12.5, 10.5, 15.5,  5.5, 12.5,  6.5,  8.5, 11.5, 12.5,
# ...

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(ytest, ypred))
print('Mean Squared Error:', metrics.mean_squared_error(ytest, ypred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(ytest, ypred)))
# Out:
# Mean Absolute Error: 0.0
# Mean Squared Error: 0.0
# Root Mean Squared Error: 0.0
